# %%
import mindspore as ms
import mindspore.ops as ops
import numpy as np
import time

ms.set_context(device_target="Ascend")

A = ms.Tensor(np.ones((2048, 2048), np.float16))
B = ms.Tensor(np.ones((2048, 1), np.float16))
# Out:
# /root/tools/anaconda3/envs/ocr-9/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /root/tools/anaconda3/envs/ocr-9/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /root/tools/anaconda3/envs/ocr-9/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /root/tools/anaconda3/envs/ocr-9/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# ...

# %%
C = ops.MatMul()(A, B)
sum = 0.0
for _ in range(10000):
    start = time.time()
    C = ops.MatMul()(A, B)
    end = time.time()
    sum += (end - start) * 1000
print("MindSpore Ascend Average Time:", sum / 10000, "ms")
# Out:
# MindSpore Ascend Average Time: 0.0706289529800415 ms
